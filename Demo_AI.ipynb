# %% [markdown]
# ##Library

# %%
import copy
import heapq
import json
from timeit import default_timer as timer
import os
import psutil
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Statistic data collect

# %%
def get_process_memory():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss

def memory_used():
  mem = psutil.virtual_memory()[2]
  return mem
def profile(store):
    def prof_stor(func):
        def wrapper(*args, **kwargs):
            mem_before = get_process_memory()
            visited = set()
            itr = [0,0]
            start = timer()
            try:
                result = func(*args, visited, itr, **kwargs)          
            except Exception as e:
                print(e)
                result = None
            elapsed_time = timer() - start
            mem_after = get_process_memory()
            
            if result and store:
                print('//---------------------// \nFinal ', end='')
                result.print_state()
                stats[store]= {
                    'elapsed_time' : elapsed_time,                 
                    #'memory' : mem_after - mem_before,
                    'iters' : itr[0],
                    'path_length': itr[1],
                    'cpu' : psutil.cpu_percent(4),
                    }
            else:
                print('No Soluton found !')
                stats[store]= {
                    'elapsed_time' : elapsed_time,
                    #'memory' : mem_after - mem_before,
                    'iters' : 0,
                    'path_length': 0,
                    'cpu' : psutil.cpu_percent(4),
                    }
            return result
        return wrapper
    return prof_stor

# %% [markdown]
# ## Game

# %%
#Function For Random Initial State Input
def random_Input(n): # n = number of row and column
  randInput = []
  testInput = []
  indexInput = 0
  while(len(randInput) < n*n):
    randnum = random.randint(1, n)      
    if randInput.count(randnum) < n :
      randInput.append(randnum)       
  
  for i in range(n):
    sliceRow = []
    for j in range(n):
      indexValue = randInput[indexInput]
      if(indexValue == 1):
        value = '🟥'
      elif(indexValue == 2):
        value = '🟨'
      elif(indexValue == 3):
        value = '🟦'
      elif(indexValue == 4):
        value = '🟩'
      elif(indexValue == 5):
        value = '⬜️'
        
      sliceRow.append(value)
      indexInput += 1 
    #sliceRow = str(sliceRow).replace('[','').replace(']','')
    testInput.append(sliceRow)

  return testInput
  #dis = ['🟥,🟥,🟥,🟥','🟨,🟨,🟨,🟨','🟦,🟦,🟦,🟦','🟩,🟩,🟩,🟩'] Example input

# %%
stats = {}

class Board:
    def __init__(self, n: int):
        self.size = n
        self.state = []

    def __eq__(self, other):
        return self.h() == other.h()
    def __lt__(self, other):
        return self.h() < other.h()

    def is_goal_state(self):
        return self.h() == 0

    def h(self):
        dist = 0
        val = 0
        for i in range(0, self.size):
            for j in range(0, self.size):
                dir_x = [1,0,-1,0]
                dir_y = [0,1,0,-1]
                for k in range(0, 4):
                    new_x = i+dir_x[k]
                    new_y = j+dir_y[k]
                    if new_x >=0 and new_x <self.size and new_y >=0 and new_y < self.size:
                        if self.state[new_x][new_y] == self.state[i][j]:
                            dist+=1
        return dist

    def input_state(self,n):
        #dis = ['🟥,🟥,🟦,🟦','🟨,🟥,🟩,🟨','🟥,🟨,🟦,🟨','🟨,🟦,🟩,🟥']
        dis = random_Input(n) # Set 4 mean 4x4  if 5 is 5x5
        n = self.size
        print('Enter the colour Board state as {0}x{0} matrix, elements separated by a {1}:'.format(n, '","'))
        for i in dis:
            #row = i.split(',') #*******************Comment this if use Random Input***********************
            self.state.append(i)
        self.validate_input()

    def validate_input(self):
        vals = []
        for i in range(0, self.size):
            print(self.state[i])
            if len(self.state[i]) != self.size:
                raise AssertionError('Board specified is not square')
        for i in range(0, self.size):
            for j in range(0, self.size):
                if str(self.state[i][j]).strip() not in ["🟥","🟩","🟦","🟨","⬜️"]:
                    raise AssertionError('Invalid Colour')
                else:
                    self.state[i][j] = str(self.state[i][j]).strip()

    def print_state(self):
        n = self.size
        print('Board state: ')
        for i in range(0, n):
          for j in range(0, n):
            print(self.state[i][j], end = '')
          print('')

    def generate_states(self):
        n = self.size
        new_states = []
        for i in range(0, n):
            for j in range(0, n):
                dir_x = [1,0,-1,0]
                dir_y = [0,1,0,-1]
                bad = False
                for k in range(0, 4):
                    new_x = i+dir_x[k]
                    new_y = j+dir_y[k]
                    if new_x >=0 and new_x <self.size and new_y >=0 and new_y < self.size:
                        if self.state[new_x][new_y] == self.state[i][j]:
                            bad = True
                if not bad:
                    continue
                for k in range(0, 4):
                    new_x = i+dir_x[k]
                    new_y = j+dir_y[k]
                    if new_x >=0 and new_x <self.size and new_y >=0 and new_y < self.size:
                        if self.state[new_x][new_y] != self.state[i][j]:
                            nboard = Board(n)
                            nboard.state = copy.deepcopy(self.state)
                            nboard.state[new_x][new_y], nboard.state[i][j] = nboard.state[i][j], nboard.state[new_x][new_y]
                            new_states.append(nboard)
        return new_states

    def generate_states_bfs(self):
            n = self.size
            new_states = []
            
            for i in range(0, n):
                for j in range(0, n):
                    dir_x = [1,0,-1,0]
                    dir_y = [0,1,0,-1]
                    bad = False              
                    
                    for k in range(0, 4):
                        new_x = i+dir_x[k]
                        new_y = j+dir_y[k]
                        if new_x >=0 and new_x <self.size and new_y >=0 and new_y < self.size:
                            if self.state[new_x][new_y] != self.state[i][j]:
                                nboard = Board(n)
                                nboard.state = copy.deepcopy(self.state)
                                nboard.state[new_x][new_y], nboard.state[i][j] = nboard.state[i][j], nboard.state[new_x][new_y]
                                new_states.append(nboard)
            return new_states

# %% [markdown]
# ## Search Alg

# %%
########################
##  Search Algorithms ##
########################

## BFS Algorithm
@profile(store='bfs')
def bfs(cur_state, visited, itr):
    print('BFS Initial ', end='')
    cur_state.print_state()

    qu = []
    qu.append((cur_state, 0))
    parent = {}

    while(len(qu) != 0):
        itr[0]+=1
        cst, depth = qu.pop(0)
        print('')
        print('itr :',itr[0],' depth:',depth)
        
        cst.print_state()
        if cst.is_goal_state():
            itr[1] = depth
            return cst
        for state in cst.generate_states_bfs():
            y = repr(state.state)
            
            if y not in visited:
                visited.add(y)
                parent[y] = cst
                qu.append((state, depth+1))

    return None

def print_path(parents, goal, initial):
     print(parents)
     temp = goal
     while repr(temp.state) in parents.keys() and repr(temp.state) != repr(initial.state):
         temp.print_state()
         temp = parents[repr(temp.state)]
     temp.print_state()

## A* Algorithm
@profile(store='A*')
def a_star(cur_state, visited, itr):
    print('A* Initial ', end='')
    cur_state.print_state()

    hp = []
    heapq.heappush(hp, (0+cur_state.h(), 0, cur_state))
    parent = {}
    while(len(hp) != 0):
        itr[0]+=1
        top_ele = heapq.heappop(hp)
        cst = top_ele[2]
        #print('cst here',cst)
        if cst.is_goal_state():
            itr[1] = top_ele[1]
            print_path(parent, cst, cur_state)
            return cst
        cur_steps = top_ele[1]
        for state in cst.generate_states():
            y = repr(state.state)
            if y not in visited:
                visited.add(y)
                parent[y] = cst
                cost = cur_steps+1+state.h()
                heapq.heappush(hp, (cost, cur_steps+1, state))

    return None

# %% [markdown]
# #Board 3x3

# %% [markdown]
# ###Initial Board

# %%
board3x3 = Board(int(3))
board3x3.input_state(3)
# Out:
# Enter the colour Board state as 3x3 matrix, elements separated by a ",":
# ['\U0001f7e6', '\U0001f7e8', '\U0001f7e5']
# ['\U0001f7e8', '\U0001f7e8', '\U0001f7e5']
# ['\U0001f7e6', '\U0001f7e5', '\U0001f7e6']

# %% [markdown]
# ###BFS Run

# %%
#---BFS Run---
bfs(board3x3)
# Out:
# BFS Initial Board state:
# 🟦🟨🟥
# 🟨🟨🟥
# 🟦🟥🟦
#
# itr : 1  depth: 0
# Board state:
# 🟦🟨🟥
# 🟨🟨🟥
# 🟦🟥🟦
#
# itr : 2  depth: 1
# Board state:
# 🟨🟨🟥
# 🟦🟨🟥
# 🟦🟥🟦
#
# itr : 3  depth: 1
# Board state:
# 🟨🟦🟥
# 🟨🟨🟥
# 🟦🟥🟦
#
# itr : 4  depth: 1
# Board state:
# 🟦🟥🟨
# 🟨🟨🟥
# 🟦🟥🟦
#
# itr : 5  depth: 1
# Board state:
# 🟦🟨🟥
# 🟦🟨🟥
# 🟨🟥🟦
#
# itr : 6  depth: 1
# Board state:
# 🟦🟨🟥
# 🟨🟥🟥
# 🟦🟨🟦
#
# itr : 7  depth: 1
# Board state:
# 🟦🟨🟥
# 🟨🟥🟨
# 🟦🟥🟦
#
# itr : 8  depth: 1
# Board state:
# 🟦🟨🟥
# 🟨🟨🟦
# 🟦🟥🟥
#
# itr : 9  depth: 1
# Board state:
# 🟦🟨🟥
# 🟨🟨🟥
# 🟥🟦🟦
#
# itr : 10  depth: 1
# Board state:
# 🟦🟨🟥
# 🟨🟨🟥
# 🟦🟦🟥
#
# itr : 11  depth: 2
# Board state:
# 🟦🟨🟥
# 🟨🟨🟥
# 🟦🟥🟦
#
# itr : 12  depth: 2
# Board state:
# 🟨🟥🟨
# 🟦🟨🟥
# 🟦🟥🟦
#
# itr : 13  depth: 2
# Board state:
# 🟨🟨🟥
# 🟨🟦🟥
# 🟦🟥🟦
#
# itr : 14  depth: 2
# Board state:
# 🟨🟨🟥
# 🟦🟥🟥
# 🟦🟨🟦
#
# itr : 15  depth: 2
# Board state:
# 🟨🟨🟥
# 🟦🟥🟨
# 🟦🟥🟦
#
# itr : 16  depth: 2
# Board state:
# 🟨🟨🟥
# 🟦🟨🟦
# 🟦🟥🟥
#
# itr : 17  depth: 2
# Board state:
# 🟨🟨🟥
# 🟦🟨🟥
# 🟥🟦🟦
#
# itr : 18  depth: 2
# Board state:
# 🟨🟨🟥
# 🟦🟨🟥
# 🟦🟦🟥
#
# itr : 19  depth: 2
# Board state:
# 🟨🟥🟦
# 🟨🟨🟥
# 🟦🟥🟦
#
# itr : 20  depth: 2
# Board state:
# 🟨🟦🟥
# 🟦🟨🟥
# 🟨🟥🟦
#
# itr : 21  depth: 2
# Board state:
# 🟨🟦🟥
# 🟨🟥🟥
# 🟦🟨🟦
#
# itr : 22  depth: 2
# Board state:
# 🟨🟦🟥
# 🟨🟥🟨
# 🟦🟥🟦
#
# itr : 23  depth: 2
# Board state:
# 🟨🟦🟥
# 🟨🟨🟦
# 🟦🟥🟥
#
# itr : 24  depth: 2
# Board state:
# 🟨🟦🟥
# 🟨🟨🟥
# 🟥🟦🟦
#
# itr : 25  depth: 2
# Board state:
# 🟨🟦🟥
# 🟨🟨🟥
# 🟦🟦🟥
#
# itr : 26  depth: 2
# Board state:
# 🟥🟦🟨
# 🟨🟨🟥
# 🟦🟥🟦
#
# itr : 27  depth: 2
# Board state:
# 🟦🟨🟨
# 🟨🟥🟥
# 🟦🟥🟦
#
# itr : 28  depth: 2
# Board state:
# 🟦🟥🟥
# 🟨🟨🟨
# 🟦🟥🟦
#
# itr : 29  depth: 2
# Board state:
# 🟦🟥🟨
# 🟦🟨🟥
# 🟨🟥🟦
#
# itr : 30  depth: 2
# Board state:
# 🟦🟥🟨
# 🟨🟥🟥
# 🟦🟨🟦
#
# itr : 31  depth: 2
# Board state:
# 🟦🟥🟨
# 🟨🟥🟨
# 🟦🟥🟦
#
# itr : 32  depth: 2
# Board state:
# 🟦🟥🟨
# 🟨🟨🟦
# 🟦🟥🟥
#
# itr : 33  depth: 2
# Board state:
# 🟦🟥🟨
# 🟨🟨🟥
# 🟥🟦🟦
#
# itr : 34  depth: 2
# Board state:
# 🟦🟥🟨
# 🟨🟨🟥
# 🟦🟦🟥
#
# itr : 35  depth: 2
# Board state:
# 🟦🟨🟥
# 🟨🟦🟥
# 🟨🟥🟦
#
# itr : 36  depth: 2
# Board state:
# 🟦🟨🟥
# 🟦🟥🟥
# 🟨🟨🟦
#
# itr : 37  depth: 2
# Board state:
# 🟦🟨🟥
# 🟦🟥🟨
# 🟨🟥🟦
#
# itr : 38  depth: 2
# Board state:
# 🟦🟨🟥
# 🟦🟨🟦
# 🟨🟥🟥
#
# itr : 39  depth: 2
# Board state:
# 🟦🟨🟥
# 🟦🟨🟥
# 🟥🟨🟦
#
# itr : 40  depth: 2
# Board state:
# 🟦🟨🟥
# 🟦🟨🟥
# 🟨🟦🟥
#
# itr : 41  depth: 2
# Board state:
# 🟦🟥🟥
# 🟨🟨🟥
# 🟦🟨🟦
#
# itr : 42  depth: 2
# Board state:
# 🟦🟨🟥
# 🟥🟨🟥
# 🟦🟨🟦
#
# itr : 43  depth: 2
# Board state:
# 🟦🟨🟥
# 🟨🟥🟦
# 🟦🟨🟥
# //---------------------//
# Final Board state:
# 🟦🟨🟥
# 🟨🟥🟦
# 🟦🟨🟥

# %% [markdown]
# ###3x3 A-star

# %%
#---A star Run---
a_star(board3x3)
# Out:
# A* Initial Board state:
# 🟦🟨🟥
# 🟨🟨🟥
# 🟦🟥🟦
# {"[['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc8547da5d0>, "[['\\U0001f7e8', '\\U0001f7e6', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc8547da5d0>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc8547da5d0>, "[['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc8547da5d0>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e6']]": <__main__.Board object at 0x7fc8547da5d0>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc8547da5d0>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e6'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e5']]": <__main__.Board object at 0x7fc8547da5d0>, "[['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc854766f50>, "[['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc854766f50>, "[['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e6']]": <__main__.Board object at 0x7fc854766f50>, "[['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc854766f50>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e8'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc854766f50>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc856dd9ed0>, "[['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e8'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc856dd9ed0>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e8', '\\U0001f7e8'], ['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc856dd9ed0>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e6', '\\U0001f7e6', '\\U0001f7e5']]": <__main__.Board object at 0x7fc856dd9ed0>, "[['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e6']]": <__main__.Board object at 0x7fc856dd9ed0>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e8'], ['\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc854766590>, "[['\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e8', '\\U0001f7e6', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e6']]": <__main__.Board object at 0x7fc854766590>}
# Board state:
# 🟥🟦🟨
# 🟦🟨🟥
# 🟨🟥🟦
# Board state:
# 🟦🟥🟨
# 🟦🟨🟥
# 🟨🟥🟦
# Board state:
# 🟦🟥🟨
# 🟨🟨🟥
# 🟦🟥🟦
# Board state:
# 🟦🟨🟥
# 🟨🟨🟥
# 🟦🟥🟦
# //---------------------//
# Final Board state:
# 🟥🟦🟨
# 🟦🟨🟥
# 🟨🟥🟦

# %%
#print(json.dumps(stats, indent = 4))
jfile = json.dumps(stats, indent = 4)
print(jfile)
# Out:
# {
#     "bfs": {
#         "elapsed_time": 0.1135439800000313,
#         "iters": 43,
#         "path_length": 2,
#         "cpu": 7.0
#     },
#     "A*": {
#         "elapsed_time": 0.008087954999609792,
#         "iters": 5,
#         "path_length": 3,
#         "cpu": 36.8
#     }
# }

# %% [markdown]
# #Board 4x4

# %%
board4x4 = Board(int(4))
board4x4.input_state(4)
# Out:
# Enter the colour Board state as 4x4 matrix, elements separated by a ",":
# ['\U0001f7e5', '\U0001f7e6', '\U0001f7e5', '\U0001f7e6']
# ['\U0001f7e8', '\U0001f7e9', '\U0001f7e6', '\U0001f7e6']
# ['\U0001f7e9', '\U0001f7e9', '\U0001f7e8', '\U0001f7e5']
# ['\U0001f7e5', '\U0001f7e9', '\U0001f7e8', '\U0001f7e8']

# %%
#---BFS Run---
bfs(board4x4)
# Out:
# Streaming output truncated to the last 5000 lines.
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 470  depth: 3
# Board state:
# 🟥🟥🟦🟩
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 471  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟩🟦🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 472  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟦🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 473  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟩🟦🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 474  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟦🟨🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 475  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟦🟦🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 476  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟦🟦🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 477  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟦🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 478  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟦🟦🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 479  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 480  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 481  depth: 3
# Board state:
# 🟥🟥🟩🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 482  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟩🟦🟥🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 483  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟦🟨🟥🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 484  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟩🟥🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 485  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟨🟦
# 🟩🟩🟥🟥
# 🟥🟩🟨🟨
#
# itr : 486  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟦🟥
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 487  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟥🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 488  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟥🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 489  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟥🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 490  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟥🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 491  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟥🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 492  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟥🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 493  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟦🟥🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 494  depth: 3
# Board state:
# 🟥🟦🟩🟥
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 495  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟩🟦🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 496  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟦🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 497  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟩🟦🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 498  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟦🟨🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 499  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟦🟦🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 500  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟦🟦🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 501  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟦🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 502  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟦🟦🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 503  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟦🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 504  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 505  depth: 3
# Board state:
# 🟥🟩🟦🟥
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 506  depth: 3
# Board state:
# 🟩🟩🟥🟦
# 🟥🟦🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 507  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟩🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 508  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟩🟦🟦
# 🟨🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 509  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟨🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 510  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟦🟥
# 🟨🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 511  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟦🟦
# 🟥🟩🟨🟥
# 🟨🟩🟨🟨
#
# itr : 512  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟨🟨
#
# itr : 513  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟦🟦
# 🟨🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 514  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟦🟦
# 🟨🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 515  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟦🟦
# 🟨🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 516  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟦🟦
# 🟨🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 517  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟦🟦🟦
# 🟨🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 518  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟨🟦🟦
# 🟦🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 519  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟩🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟨🟨
#
# itr : 520  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟦🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 521  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟨🟨🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 522  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟨🟦🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 523  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟨🟦🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 524  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟨🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 525  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟨🟦🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 526  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟨🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 527  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟨🟦🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 528  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟦🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 529  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟩🟨🟦🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 530  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟩🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 531  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟨🟦
# 🟩🟦🟦🟥
# 🟥🟩🟨🟨
#
# itr : 532  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟥
# 🟩🟦🟨🟦
# 🟥🟩🟨🟨
#
# itr : 533  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟦
# 🟥🟦🟨🟥
# 🟩🟩🟨🟨
#
# itr : 534  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟦
# 🟦🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 535  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟥🟦🟨🟨
#
# itr : 536  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟦
# 🟩🟨🟦🟥
# 🟥🟩🟨🟨
#
# itr : 537  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟦
# 🟩🟦🟥🟨
# 🟥🟩🟨🟨
#
# itr : 538  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟦
# 🟩🟦🟨🟨
# 🟥🟩🟨🟥
#
# itr : 539  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟦
# 🟩🟦🟨🟥
# 🟩🟥🟨🟨
#
# itr : 540  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟩🟦🟦
# 🟩🟦🟨🟥
# 🟥🟨🟩🟨
#
# itr : 541  depth: 3
# Board state:
# 🟥🟩🟨🟦
# 🟨🟦🟥🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 542  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟨🟦🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 543  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟨
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 544  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟨🟥
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 545  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟨🟦
# 🟥🟩🟦🟥
# 🟩🟩🟨🟨
#
# itr : 546  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟨🟦
# 🟩🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 547  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟦🟨
#
# itr : 548  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 549  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟥
#
# itr : 550  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟦🟥
# 🟩🟥🟨🟨
#
# itr : 551  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟦🟥
# 🟥🟨🟩🟨
#
# itr : 552  depth: 3
# Board state:
# 🟥🟩🟥🟥
# 🟨🟦🟦🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 553  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟥🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 554  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟥
# 🟥🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 555  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟥
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 556  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟥
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 557  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟥
# 🟩🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 558  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟥
# 🟩🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 559  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟥
# 🟩🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 560  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟥🟦🟦🟦
# 🟨🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 561  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟥🟨🟥
# 🟩🟩🟨🟨
#
# itr : 562  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟥🟨🟩🟥
# 🟩🟩🟨🟨
#
# itr : 563  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟥🟩🟥🟨
# 🟩🟩🟨🟨
#
# itr : 564  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟥🟩🟨🟨
# 🟩🟩🟨🟥
#
# itr : 565  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟥🟩🟨🟥
# 🟩🟨🟩🟨
#
# itr : 566  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟨🟦🟦
# 🟩🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 567  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟩🟦
# 🟩🟨🟦🟥
# 🟥🟩🟨🟨
#
# itr : 568  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟨🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 569  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟩🟥
# 🟥🟨🟨🟨
#
# itr : 570  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟩🟨
#
# itr : 571  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟨🟥🟩
# 🟥🟩🟨🟨
#
# itr : 572  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟨🟩🟨
# 🟥🟩🟨🟥
#
# itr : 573  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟨🟩🟥
# 🟩🟥🟨🟨
#
# itr : 574  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟨🟩🟥
# 🟥🟨🟩🟨
#
# itr : 575  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟥🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 576  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟨
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 577  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟥🟩🟨
# 🟥🟩🟨🟨
#
# itr : 578  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟥🟨
#
# itr : 579  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟥🟨
# 🟩🟥🟨🟨
#
# itr : 580  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟥🟨
# 🟥🟨🟩🟨
#
# itr : 581  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟨
# 🟩🟩🟨🟦
# 🟥🟩🟨🟥
#
# itr : 582  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟨
# 🟩🟥🟨🟥
#
# itr : 583  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟨
# 🟥🟨🟩🟥
#
# itr : 584  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟩🟨🟥🟨
#
# itr : 585  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟨🟥🟩🟨
#
# itr : 586  depth: 3
# Board state:
# 🟥🟩🟥🟦
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟨🟩
#
# itr : 587  depth: 3
# Board state:
# 🟩🟥🟦🟦
# 🟨🟥🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 588  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟩🟥🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 589  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟥🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 590  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟩🟦🟦
# 🟩🟥🟨🟥
# 🟥🟩🟨🟨
#
# itr : 591  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟥🟨🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 592  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟥🟦🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 593  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟥🟦🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 594  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟥🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 595  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟥🟦🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 596  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟥🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 597  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟥🟦🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 598  depth: 3
# Board state:
# 🟥🟩🟦🟦
# 🟨🟥🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 599  depth: 3
# Board state:
# 🟩🟥🟦🟦
# 🟥🟩🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 600  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟦🟩🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 601  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟨🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 602  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟦🟥
# 🟨🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 603  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟦🟦
# 🟥🟩🟨🟥
# 🟨🟩🟨🟨
#
# itr : 604  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟨🟨
#
# itr : 605  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟦🟦
# 🟨🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 606  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟦🟦
# 🟨🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 607  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 608  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 609  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 610  depth: 3
# Board state:
# 🟩🟥🟦🟦
# 🟥🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 611  depth: 3
# Board state:
# 🟥🟨🟦🟦
# 🟩🟥🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 612  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟦🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 613  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟨🟨🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 614  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟨🟦🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 615  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟨🟦🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 616  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟨🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 617  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟨🟦🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 618  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 619  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 620  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 621  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟦🟨🟩🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 622  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟩🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 623  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟨🟦
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 624  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟦🟩
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 625  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟩🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 626  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟩🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 627  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟩🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 628  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟩🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 629  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 630  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 631  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 632  depth: 3
# Board state:
# 🟥🟥🟨🟦
# 🟨🟩🟦🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 633  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟨🟩🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 634  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟨
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 635  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟨🟥
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 636  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟨🟦
# 🟥🟩🟦🟥
# 🟩🟩🟨🟨
#
# itr : 637  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟨🟦
# 🟩🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 638  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟦🟨
#
# itr : 639  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 640  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟥
#
# itr : 641  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟥
# 🟩🟥🟨🟨
#
# itr : 642  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟥
# 🟥🟨🟩🟨
#
# itr : 643  depth: 3
# Board state:
# 🟥🟥🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 644  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 645  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 646  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟥
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 647  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟥
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 648  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟥
# 🟩🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 649  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟥
# 🟩🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 650  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟥
# 🟩🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 651  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟥🟩🟦🟦
# 🟨🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 652  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟥🟨🟥
# 🟩🟩🟨🟨
#
# itr : 653  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟥🟨🟩🟥
# 🟩🟩🟨🟨
#
# itr : 654  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟥🟩🟥🟨
# 🟩🟩🟨🟨
#
# itr : 655  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟥🟩🟨🟨
# 🟩🟩🟨🟥
#
# itr : 656  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟥🟩🟨🟥
# 🟩🟨🟩🟨
#
# itr : 657  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟨🟦🟦
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 658  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟩🟦
# 🟩🟨🟦🟥
# 🟥🟩🟨🟨
#
# itr : 659  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟨🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 660  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟩🟥
# 🟥🟨🟨🟨
#
# itr : 661  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟩🟨
#
# itr : 662  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟨🟥🟩
# 🟥🟩🟨🟨
#
# itr : 663  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟨🟩🟨
# 🟥🟩🟨🟥
#
# itr : 664  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟨🟩🟥
# 🟩🟥🟨🟨
#
# itr : 665  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟨🟩🟥
# 🟥🟨🟩🟨
#
# itr : 666  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 667  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟨
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 668  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟥🟩🟨
# 🟥🟩🟨🟨
#
# itr : 669  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟥🟨
#
# itr : 670  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟥🟨
# 🟩🟥🟨🟨
#
# itr : 671  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟥🟨
# 🟥🟨🟩🟨
#
# itr : 672  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟨
# 🟩🟩🟨🟦
# 🟥🟩🟨🟥
#
# itr : 673  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟨
# 🟩🟥🟨🟥
#
# itr : 674  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟨
# 🟥🟨🟩🟥
#
# itr : 675  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟩🟨🟥🟨
#
# itr : 676  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟨🟥🟩🟨
#
# itr : 677  depth: 3
# Board state:
# 🟥🟥🟦🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟨🟩
#
# itr : 678  depth: 3
# Board state:
# 🟩🟦🟦🟦
# 🟥🟩🟥🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 679  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟥🟩🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 680  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟨🟦
# 🟨🟩🟥🟥
# 🟥🟩🟨🟨
#
# itr : 681  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟦🟥
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 682  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟥🟥
# 🟨🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 683  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟥🟦
# 🟥🟩🟨🟥
# 🟨🟩🟨🟨
#
# itr : 684  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟥🟦
# 🟩🟨🟨🟥
# 🟥🟩🟨🟨
#
# itr : 685  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟥🟦
# 🟨🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 686  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟥🟦
# 🟨🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 687  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟥🟦
# 🟨🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 688  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟥🟦
# 🟨🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 689  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟩🟥🟦
# 🟨🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 690  depth: 3
# Board state:
# 🟩🟦🟦🟦
# 🟥🟨🟥🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 691  depth: 3
# Board state:
# 🟥🟨🟦🟦
# 🟩🟦🟥🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 692  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟥🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 693  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟨🟦
# 🟩🟩🟥🟥
# 🟥🟩🟨🟨
#
# itr : 694  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟦🟥
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 695  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟥🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 696  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟥🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 697  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟥🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 698  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟥🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 699  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟥🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 700  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟥🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 701  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟩🟨🟥🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 702  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟥🟨🟩🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 703  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟩🟦
# 🟩🟥🟨🟥
# 🟥🟩🟨🟨
#
# itr : 704  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟨🟦
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 705  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟦🟩
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 706  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟩🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 707  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟩🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 708  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟩🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 709  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟩🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 710  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟩🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 711  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟩🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 712  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟥🟩🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 713  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟦🟦
# 🟩🟩🟥🟥
# 🟥🟩🟨🟨
#
# itr : 714  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟨🟩🟦
# 🟩🟩🟥🟥
# 🟥🟩🟨🟨
#
# itr : 715  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟦🟨
# 🟩🟩🟥🟥
# 🟥🟩🟨🟨
#
# itr : 716  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟨🟥
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 717  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟨🟦
# 🟥🟩🟥🟥
# 🟩🟩🟨🟨
#
# itr : 718  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟨🟦
# 🟩🟥🟩🟥
# 🟥🟩🟨🟨
#
# itr : 719  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟥🟨
#
# itr : 720  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟥
#
# itr : 721  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟥🟥
# 🟩🟥🟨🟨
#
# itr : 722  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟨🟦
# 🟩🟩🟥🟥
# 🟥🟨🟩🟨
#
# itr : 723  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟦🟩🟥
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 724  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟨🟥
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 725  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 726  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟦🟥
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 727  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟦🟥
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 728  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟦🟥
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 729  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟦🟥
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 730  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟦🟥
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 731  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟥🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 732  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟥
# 🟥🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 733  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟥
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 734  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟥
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 735  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟥
# 🟩🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 736  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟥
# 🟩🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 737  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟥
# 🟩🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 738  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟥🟩🟥🟦
# 🟨🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 739  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟥🟨🟥
# 🟩🟩🟨🟨
#
# itr : 740  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟥🟨🟩🟥
# 🟩🟩🟨🟨
#
# itr : 741  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟥🟩🟥🟨
# 🟩🟩🟨🟨
#
# itr : 742  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟥🟩🟨🟨
# 🟩🟩🟨🟥
#
# itr : 743  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟥🟩🟨🟥
# 🟩🟨🟩🟨
#
# itr : 744  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟨🟥🟦
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 745  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟩🟦
# 🟩🟨🟥🟥
# 🟥🟩🟨🟨
#
# itr : 746  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟨🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 747  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟩🟥
# 🟥🟨🟨🟨
#
# itr : 748  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟨🟨🟥
# 🟥🟩🟩🟨
#
# itr : 749  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟨🟥🟩
# 🟥🟩🟨🟨
#
# itr : 750  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟨🟩🟨
# 🟥🟩🟨🟥
#
# itr : 751  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟨🟩🟥
# 🟩🟥🟨🟨
#
# itr : 752  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟨🟩🟥
# 🟥🟨🟩🟨
#
# itr : 753  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟨
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 754  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟥🟩🟨
# 🟥🟩🟨🟨
#
# itr : 755  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟨
# 🟥🟩🟥🟨
#
# itr : 756  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟥🟨
# 🟩🟥🟨🟨
#
# itr : 757  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟥🟨
# 🟥🟨🟩🟨
#
# itr : 758  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟨
# 🟩🟩🟨🟦
# 🟥🟩🟨🟥
#
# itr : 759  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟨
# 🟩🟥🟨🟥
#
# itr : 760  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟨
# 🟥🟨🟩🟥
#
# itr : 761  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟥
# 🟩🟨🟥🟨
#
# itr : 762  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟥
# 🟨🟥🟩🟨
#
# itr : 763  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟥
# 🟥🟨🟨🟩
#
# itr : 764  depth: 3
# Board state:
# 🟩🟦🟦🟥
# 🟥🟩🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 765  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟦🟩🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 766  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟨🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 767  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟦🟥
# 🟨🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 768  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟦🟦
# 🟥🟩🟨🟥
# 🟨🟩🟨🟨
#
# itr : 769  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟨🟨
#
# itr : 770  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟦🟦
# 🟨🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 771  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟦🟦
# 🟨🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 772  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟦🟦
# 🟨🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 773  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟦🟦
# 🟨🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 774  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟩🟦🟦
# 🟨🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 775  depth: 3
# Board state:
# 🟩🟦🟦🟥
# 🟥🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 776  depth: 3
# Board state:
# 🟥🟨🟦🟥
# 🟩🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 777  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟦🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 778  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟨🟨🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 779  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟨🟦🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 780  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟨🟦🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 781  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟨🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 782  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟨🟦🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 783  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟨🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 784  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟨🟦🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 785  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟩🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 786  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟦🟨🟩🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 787  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟩🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 788  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟨🟦
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 789  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟦🟩
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 790  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟩🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 791  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟩🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 792  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟩🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 793  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟩🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 794  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟩🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 795  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟩🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 796  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟦🟩🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 797  depth: 3
# Board state:
# 🟥🟦🟨🟥
# 🟨🟩🟦🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 798  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟨🟩🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 799  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟨
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 800  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟨🟥
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 801  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟨🟦
# 🟥🟩🟦🟥
# 🟩🟩🟨🟨
#
# itr : 802  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟨🟦
# 🟩🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 803  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟦🟨
#
# itr : 804  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟨🟦
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 805  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟨🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟥
#
# itr : 806  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟨🟦
# 🟩🟩🟦🟥
# 🟩🟥🟨🟨
#
# itr : 807  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟨🟦
# 🟩🟩🟦🟥
# 🟥🟨🟩🟨
#
# itr : 808  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟥
# 🟥🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 809  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟥
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 810  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟥
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 811  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟥
# 🟩🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 812  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟥
# 🟩🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 813  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟥
# 🟩🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 814  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟥🟩🟦🟦
# 🟨🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 815  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟥🟨🟥
# 🟩🟩🟨🟨
#
# itr : 816  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟥🟨🟩🟥
# 🟩🟩🟨🟨
#
# itr : 817  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟥🟩🟥🟨
# 🟩🟩🟨🟨
#
# itr : 818  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟥🟩🟨🟨
# 🟩🟩🟨🟥
#
# itr : 819  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟥🟩🟨🟥
# 🟩🟨🟩🟨
#
# itr : 820  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟨🟦🟦
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 821  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟩🟦
# 🟩🟨🟦🟥
# 🟥🟩🟨🟨
#
# itr : 822  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟨🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 823  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟩🟥
# 🟥🟨🟨🟨
#
# itr : 824  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟩🟨
#
# itr : 825  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟨🟥🟩
# 🟥🟩🟨🟨
#
# itr : 826  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟨🟩🟨
# 🟥🟩🟨🟥
#
# itr : 827  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟨🟩🟥
# 🟩🟥🟨🟨
#
# itr : 828  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟨🟩🟥
# 🟥🟨🟩🟨
#
# itr : 829  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟥🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 830  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟨
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 831  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟥🟩🟨
# 🟥🟩🟨🟨
#
# itr : 832  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟥🟨
#
# itr : 833  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟥🟨
# 🟩🟥🟨🟨
#
# itr : 834  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟥🟨
# 🟥🟨🟩🟨
#
# itr : 835  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟨
# 🟩🟩🟨🟦
# 🟥🟩🟨🟥
#
# itr : 836  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟨
# 🟩🟥🟨🟥
#
# itr : 837  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟨
# 🟥🟨🟩🟥
#
# itr : 838  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟩🟨🟥🟨
#
# itr : 839  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟨🟥🟩🟨
#
# itr : 840  depth: 3
# Board state:
# 🟥🟦🟦🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟨🟩
#
# itr : 841  depth: 3
# Board state:
# 🟦🟩🟥🟦
# 🟥🟩🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 842  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟩🟥🟦🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 843  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟦🟩🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 844  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟨🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 845  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟦🟥
# 🟨🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 846  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟦🟦
# 🟥🟩🟨🟥
# 🟨🟩🟨🟨
#
# itr : 847  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟨🟨
#
# itr : 848  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟦🟦
# 🟨🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 849  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟦🟦
# 🟨🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 850  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟦🟦
# 🟨🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 851  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟦🟦
# 🟨🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 852  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟩🟦🟦
# 🟨🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 853  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟩🟦🟥🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 854  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟩🟩🟦
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 855  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟩🟦
# 🟨🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 856  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟨🟦
# 🟨🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 857  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟦🟩
# 🟨🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 858  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟩🟥
# 🟨🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 859  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟩🟦
# 🟥🟩🟨🟥
# 🟨🟩🟨🟨
#
# itr : 860  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟩🟦
# 🟩🟨🟨🟥
# 🟥🟩🟨🟨
#
# itr : 861  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟩🟦
# 🟨🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 862  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟩🟦
# 🟨🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 863  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟩🟦
# 🟨🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 864  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟩🟦
# 🟨🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 865  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟩🟦
# 🟨🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 866  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟩🟩🟥🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 867  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟩🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 868  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟨
# 🟨🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 869  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟥
# 🟨🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 870  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟥🟩🟦🟥
# 🟨🟩🟨🟨
#
# itr : 871  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟩🟨🟦🟥
# 🟥🟩🟨🟨
#
# itr : 872  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟨🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 873  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟨🟩🟨🟥
# 🟥🟩🟦🟨
#
# itr : 874  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟨🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 875  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟨🟩🟦🟨
# 🟥🟩🟨🟥
#
# itr : 876  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟨🟩🟦🟥
# 🟩🟥🟨🟨
#
# itr : 877  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟨🟩🟦🟥
# 🟥🟨🟩🟨
#
# itr : 878  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟩🟩🟦🟦
# 🟨🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 879  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟥🟦
# 🟨🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 880  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟦
# 🟨🟩🟨🟨
#
# itr : 881  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟥
# 🟩🟨🟨🟦
# 🟥🟩🟨🟨
#
# itr : 882  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟥
# 🟨🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 883  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟥
# 🟨🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 884  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟥
# 🟨🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 885  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟥
# 🟨🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 886  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟥
# 🟨🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 887  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟥🟩🟦🟦
# 🟩🟩🟨🟥
# 🟨🟩🟨🟨
#
# itr : 888  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟩🟥🟨🟥
# 🟨🟩🟨🟨
#
# itr : 889  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟥🟨🟩🟥
# 🟨🟩🟨🟨
#
# itr : 890  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟥🟩🟥🟨
# 🟨🟩🟨🟨
#
# itr : 891  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
# 🟨🟩🟨🟥
#
# itr : 892  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟥🟩🟨🟥
# 🟩🟨🟨🟨
#
# itr : 893  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟥🟩🟨🟥
# 🟨🟨🟩🟨
#
# itr : 894  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟥🟨🟨🟥
# 🟩🟩🟨🟨
#
# itr : 895  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟨🟨
#
# itr : 896  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟩🟨🟥🟨
# 🟥🟩🟨🟨
#
# itr : 897  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟩🟨🟨🟨
# 🟥🟩🟨🟥
#
# itr : 898  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟩🟨🟨🟥
# 🟩🟥🟨🟨
#
# itr : 899  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟩🟨🟨🟥
# 🟥🟨🟩🟨
#
# itr : 900  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟨🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 901  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟩🟦
# 🟨🟨🟦🟥
# 🟥🟩🟨🟨
#
# itr : 902  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟩🟥
# 🟥🟨🟨🟨
#
# itr : 903  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟨🟨🟥
# 🟥🟩🟩🟨
#
# itr : 904  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟨🟥🟩
# 🟥🟩🟨🟨
#
# itr : 905  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟨🟩🟨
# 🟥🟩🟨🟥
#
# itr : 906  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟨🟩🟥
# 🟩🟥🟨🟨
#
# itr : 907  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟨🟩🟥
# 🟥🟨🟩🟨
#
# itr : 908  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟥🟦
# 🟨🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 909  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟨
# 🟨🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 910  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟥🟩🟨
# 🟥🟩🟨🟨
#
# itr : 911  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟨
# 🟥🟩🟥🟨
#
# itr : 912  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟥🟨
# 🟩🟥🟨🟨
#
# itr : 913  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟥🟨
# 🟥🟨🟩🟨
#
# itr : 914  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟨
# 🟨🟩🟨🟦
# 🟥🟩🟨🟥
#
# itr : 915  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟨
# 🟩🟥🟨🟥
#
# itr : 916  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟨
# 🟥🟨🟩🟥
#
# itr : 917  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟩🟩🟨🟥
# 🟨🟥🟨🟨
#
# itr : 918  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟥🟨🟥
# 🟩🟩🟨🟨
#
# itr : 919  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟥
# 🟩🟨🟥🟨
#
# itr : 920  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟥
# 🟨🟥🟩🟨
#
# itr : 921  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟦🟦
# 🟨🟩🟨🟥
# 🟥🟨🟨🟩
#
# itr : 922  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟩🟨🟦🟦
# 🟥🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 923  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟦🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 924  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟨🟨🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 925  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟨🟦🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 926  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟨🟦🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 927  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟨🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 928  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟨🟦🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 929  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟨🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 930  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟨🟦🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 931  depth: 3
# Board state:
# 🟩🟦🟥🟦
# 🟥🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 932  depth: 3
# Board state:
# 🟥🟥🟨🟦
# 🟩🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 933  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟩🟦🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 934  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟦🟨🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 935  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟦🟦🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 936  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟦🟦🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 937  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟦🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 938  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟦🟦🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 939  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟦🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 940  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟦🟦🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 941  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟩🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 942  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟩🟦🟥🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 943  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟩🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 944  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟩🟨🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 945  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟦🟨
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 946  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟨🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 947  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟨🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 948  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟨🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 949  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟨🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 950  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟨🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 951  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟨🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 952  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟦🟨🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 953  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟩🟨🟥🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 954  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟨
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 955  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟨🟥
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 956  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟨🟦
# 🟥🟩🟦🟥
# 🟩🟩🟨🟨
#
# itr : 957  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟨🟦
# 🟩🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 958  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟦🟨
#
# itr : 959  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟨🟦
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 960  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟨🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟥
#
# itr : 961  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟨🟦
# 🟩🟩🟦🟥
# 🟩🟥🟨🟨
#
# itr : 962  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟨🟦
# 🟩🟩🟦🟥
# 🟥🟨🟩🟨
#
# itr : 963  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟩🟨🟦🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 964  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟥🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 965  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟥
# 🟥🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 966  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟥
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 967  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟥
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 968  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟥
# 🟩🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 969  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟥
# 🟩🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 970  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟥
# 🟩🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 971  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟥🟨🟦🟦
# 🟩🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 972  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟥🟨🟥
# 🟩🟩🟨🟨
#
# itr : 973  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟥🟨🟩🟥
# 🟩🟩🟨🟨
#
# itr : 974  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟥🟩🟥🟨
# 🟩🟩🟨🟨
#
# itr : 975  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟥🟩🟨🟨
# 🟩🟩🟨🟥
#
# itr : 976  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟥🟩🟨🟥
# 🟩🟨🟩🟨
#
# itr : 977  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟩🟦
# 🟩🟨🟦🟥
# 🟥🟩🟨🟨
#
# itr : 978  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟩🟥
# 🟥🟨🟨🟨
#
# itr : 979  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟨🟨🟥
# 🟥🟩🟩🟨
#
# itr : 980  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟨🟥🟩
# 🟥🟩🟨🟨
#
# itr : 981  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟨🟩🟨
# 🟥🟩🟨🟥
#
# itr : 982  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟨🟩🟥
# 🟩🟥🟨🟨
#
# itr : 983  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟨🟩🟥
# 🟥🟨🟩🟨
#
# itr : 984  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟥🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 985  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟨
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 986  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟥🟩🟨
# 🟥🟩🟨🟨
#
# itr : 987  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟥🟨
#
# itr : 988  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟥🟨
# 🟩🟥🟨🟨
#
# itr : 989  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟥🟨
# 🟥🟨🟩🟨
#
# itr : 990  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟨
# 🟩🟩🟨🟦
# 🟥🟩🟨🟥
#
# itr : 991  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟨
# 🟩🟥🟨🟥
#
# itr : 992  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟨
# 🟥🟨🟩🟥
#
# itr : 993  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟥
# 🟩🟨🟥🟨
#
# itr : 994  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟥
# 🟨🟥🟩🟨
#
# itr : 995  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟦🟦
# 🟩🟩🟨🟥
# 🟥🟨🟨🟩
#
# itr : 996  depth: 3
# Board state:
# 🟥🟦🟦🟩
# 🟨🟦🟥🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 997  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟦🟨🟥🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 998  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟩🟥🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 999  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟨🟦
# 🟩🟩🟥🟥
# 🟥🟩🟨🟨
#
# itr : 1000  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟦🟥
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1001  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟥🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 1002  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟥🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 1003  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟥🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1004  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟥🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 1005  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟥🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 1006  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟥🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 1007  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟦🟥🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 1008  depth: 3
# Board state:
# 🟦🟦🟥🟦
# 🟥🟨🟩🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1009  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟦🟦🟩🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1010  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟩🟦
# 🟦🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1011  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟩🟩🟦
# 🟩🟨🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1012  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟨🟦
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1013  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟦🟩
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1014  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟩🟥
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 1015  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟩🟦
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 1016  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟩🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1017  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟩🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 1018  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟩🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 1019  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟩🟦
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 1020  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟦🟨🟩🟦
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 1021  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟩🟨🟩🟦
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1022  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟩
# 🟩🟦🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1023  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟥
# 🟩🟦🟨🟦
# 🟥🟩🟨🟨
#
# itr : 1024  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟦
# 🟥🟦🟨🟥
# 🟩🟩🟨🟨
#
# itr : 1025  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟦
# 🟦🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1026  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟦
# 🟩🟩🟨🟥
# 🟥🟦🟨🟨
#
# itr : 1027  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟦
# 🟩🟦🟥🟨
# 🟥🟩🟨🟨
#
# itr : 1028  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟦
# 🟩🟦🟨🟨
# 🟥🟩🟨🟥
#
# itr : 1029  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟦
# 🟩🟦🟨🟥
# 🟩🟥🟨🟨
#
# itr : 1030  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟦
# 🟩🟦🟨🟥
# 🟥🟨🟩🟨
#
# itr : 1031  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟦🟥🟦
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1032  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟦🟨
# 🟩🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1033  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟨🟥
# 🟩🟩🟩🟦
# 🟥🟩🟨🟨
#
# itr : 1034  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟨🟦
# 🟥🟩🟩🟥
# 🟩🟩🟨🟨
#
# itr : 1035  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟩🟨
#
# itr : 1036  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟥🟩
# 🟥🟩🟨🟨
#
# itr : 1037  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟩🟨
# 🟥🟩🟨🟥
#
# itr : 1038  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟩🟥
# 🟩🟥🟨🟨
#
# itr : 1039  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟨🟦
# 🟩🟩🟩🟥
# 🟥🟨🟩🟨
#
# itr : 1040  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟦🟥🟩
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1041  depth: 3
# Board state:
# 🟥🟦🟥🟩
# 🟨🟦🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
#
# itr : 1042  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟨🟩
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1043  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟦🟥
# 🟩🟩🟨🟩
# 🟥🟩🟨🟨
#
# itr : 1044  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟦🟩
# 🟥🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 1045  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟦🟩
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1046  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟦🟩
# 🟩🟩🟥🟨
# 🟥🟩🟨🟨
#
# itr : 1047  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟦🟩
# 🟩🟩🟨🟨
# 🟥🟩🟨🟥
#
# itr : 1048  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟦🟩
# 🟩🟩🟨🟥
# 🟩🟥🟨🟨
#
# itr : 1049  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟦🟩
# 🟩🟩🟨🟥
# 🟥🟨🟩🟨
#
# itr : 1050  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟨🟦🟩🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 1051  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟥🟩
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 1052  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟥
# 🟥🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 1053  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟥
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 1054  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟥
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 1055  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟥
# 🟩🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 1056  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟥
# 🟩🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 1057  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟥
# 🟩🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 1058  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟥🟦🟩🟦
# 🟨🟩🟨🟥
# 🟩🟩🟨🟨
#
# itr : 1059  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟥🟨🟥
# 🟩🟩🟨🟨
#
# itr : 1060  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟥🟨🟩🟥
# 🟩🟩🟨🟨
#
# itr : 1061  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟥🟩🟥🟨
# 🟩🟩🟨🟨
#
# itr : 1062  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟥🟩🟨🟨
# 🟩🟩🟨🟥
#
# itr : 1063  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟥🟩🟨🟥
# 🟩🟨🟩🟨
#
# itr : 1064  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟩🟦
# 🟩🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1065  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟨🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1066  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟩🟥
# 🟥🟨🟨🟨
#
# itr : 1067  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟨🟨🟥
# 🟥🟩🟩🟨
#
# itr : 1068  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟨🟥🟩
# 🟥🟩🟨🟨
#
# itr : 1069  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟨🟩🟨
# 🟥🟩🟨🟥
#
# itr : 1070  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟨🟩🟥
# 🟩🟥🟨🟨
#
# itr : 1071  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟨🟩🟥
# 🟥🟨🟩🟨
#
# itr : 1072  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟥🟦
# 🟩🟩🟩🟨
# 🟥🟩🟨🟨
#
# itr : 1073  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟨
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 1074  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟥🟩🟨
# 🟥🟩🟨🟨
#
# itr : 1075  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟨
# 🟥🟩🟥🟨
#
# itr : 1076  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟥🟨
# 🟩🟥🟨🟨
#
# itr : 1077  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟥🟨
# 🟥🟨🟩🟨
#
# itr : 1078  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟨
# 🟩🟩🟨🟦
# 🟥🟩🟨🟥
#
# itr : 1079  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟨
# 🟩🟥🟨🟥
#
# itr : 1080  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟨
# 🟥🟨🟩🟥
#
# itr : 1081  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟥
# 🟩🟨🟥🟨
#
# itr : 1082  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟥
# 🟨🟥🟩🟨
#
# itr : 1083  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟨🟥
# 🟥🟨🟨🟩
#
# itr : 1084  depth: 3
# Board state:
# 🟥🟨🟦🟦
# 🟨🟩🟥🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1085  depth: 3
# Board state:
# 🟥🟦🟦🟨
# 🟨🟩🟥🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1086  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟥🟩🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1087  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟦🟥
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1088  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟥🟥
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 1089  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟥🟦
# 🟥🟩🟦🟥
# 🟩🟩🟨🟨
#
# itr : 1090  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟥🟦
# 🟩🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1091  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟥
# 🟥🟩🟦🟨
#
# itr : 1092  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟥🟦
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 1093  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟥🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟥
#
# itr : 1094  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟥🟦
# 🟩🟩🟦🟥
# 🟩🟥🟨🟨
#
# itr : 1095  depth: 3
# Board state:
# 🟥🟦🟨🟦
# 🟨🟩🟥🟦
# 🟩🟩🟦🟥
# 🟥🟨🟩🟨
#
# itr : 1096  depth: 3
# Board state:
# 🟥🟨🟥🟦
# 🟨🟦🟩🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1097  depth: 3
# Board state:
# 🟥🟦🟩🟦
# 🟨🟨🟥🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1098  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟦🟩
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1099  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟩🟥
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 1100  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟩🟦
# 🟥🟩🟦🟥
# 🟩🟩🟨🟨
#
# itr : 1101  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟩🟦
# 🟩🟩🟨🟥
# 🟥🟩🟦🟨
#
# itr : 1102  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟩🟦
# 🟩🟩🟥🟦
# 🟥🟩🟨🟨
#
# itr : 1103  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟩🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟥
#
# itr : 1104  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟩🟦
# 🟩🟩🟦🟥
# 🟩🟥🟨🟨
#
# itr : 1105  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟩🟦
# 🟩🟩🟦🟥
# 🟥🟨🟩🟨
#
# itr : 1106  depth: 3
# Board state:
# 🟥🟦🟦🟦
# 🟨🟩🟥🟨
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1107  depth: 3
# Board state:
# 🟥🟦🟥🟨
# 🟨🟩🟦🟦
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1108  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟦🟩🟨
# 🟩🟩🟦🟥
# 🟥🟩🟨🟨
#
# itr : 1109  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟨
# 🟥🟩🟦🟥
# 🟩🟩🟨🟨
#
# itr : 1110  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟨
# 🟩🟦🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1111  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟨
# 🟩🟩🟨🟥
# 🟥🟩🟦🟨
#
# itr : 1112  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟨
# 🟩🟩🟦🟨
# 🟥🟩🟨🟥
#
# itr : 1113  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟨
# 🟩🟩🟦🟥
# 🟩🟥🟨🟨
#
# itr : 1114  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟨
# 🟩🟩🟦🟥
# 🟥🟨🟩🟨
#
# itr : 1115  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟨🟩🟨🟦
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 1116  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟥🟨
# 🟩🟩🟦🟦
# 🟥🟩🟨🟨
#
# itr : 1117  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟥
# 🟥🟩🟦🟦
# 🟩🟩🟨🟨
#
# itr : 1118  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟥
# 🟩🟦🟩🟦
# 🟥🟩🟨🟨
#
# itr : 1119  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟥
# 🟩🟩🟨🟦
# 🟥🟩🟦🟨
#
# itr : 1120  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟥
# 🟩🟩🟦🟨
# 🟥🟩🟨🟦
#
# itr : 1121  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟥
# 🟩🟩🟦🟦
# 🟩🟥🟨🟨
#
# itr : 1122  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟥
# 🟩🟩🟦🟦
# 🟥🟨🟩🟨
#
# itr : 1123  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟥🟩🟨🟦
# 🟨🟩🟦🟥
# 🟩🟩🟨🟨
#
# itr : 1124  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟥🟦🟥
# 🟩🟩🟨🟨
#
# itr : 1125  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟥🟦🟩🟥
# 🟩🟩🟨🟨
#
# itr : 1126  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟥🟩🟨🟥
# 🟩🟩🟦🟨
#
# itr : 1127  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟥🟩🟥🟦
# 🟩🟩🟨🟨
#
# itr : 1128  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟥🟩🟦🟨
# 🟩🟩🟨🟥
#
# itr : 1129  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟥🟩🟦🟥
# 🟩🟨🟩🟨
#
# itr : 1130  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟦🟩🟩🟥
# 🟥🟩🟨🟨
#
# itr : 1131  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟩🟥
# 🟥🟦🟨🟨
#
# itr : 1132  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟦🟨🟥
# 🟥🟩🟩🟨
#
# itr : 1133  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟦🟥🟩
# 🟥🟩🟨🟨
#
# itr : 1134  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟦🟩🟨
# 🟥🟩🟨🟥
#
# itr : 1135  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟦🟩🟥
# 🟩🟥🟨🟨
#
# itr : 1136  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟦🟩🟥
# 🟥🟨🟩🟨
#
# itr : 1137  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟨🟩🟥
# 🟥🟩🟦🟨
#
# itr : 1138  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟥🟨
# 🟥🟩🟦🟨
#
# itr : 1139  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟨🟨
# 🟥🟩🟦🟥
#
# itr : 1140  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟨🟥
# 🟩🟥🟦🟨
#
# itr : 1141  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟨🟥
# 🟥🟦🟩🟨
#
# itr : 1142  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟦
#
# itr : 1143  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟥🟩🟦
# 🟥🟩🟨🟨
#
# itr : 1144  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟨🟦
# 🟥🟩🟥🟨
#
# itr : 1145  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟥🟨
# 🟥🟩🟨🟦
#
# itr : 1146  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟥🟦
# 🟩🟥🟨🟨
#
# itr : 1147  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟥🟦
# 🟥🟨🟩🟨
#
# itr : 1148  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟨
# 🟩🟩🟦🟦
# 🟥🟩🟨🟥
#
# itr : 1149  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟥
#
# itr : 1150  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟨
# 🟩🟥🟨🟥
#
# itr : 1151  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟨
# 🟥🟨🟩🟥
#
# itr : 1152  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟨
# 🟥🟩🟥🟨
#
# itr : 1153  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟥
# 🟩🟨🟥🟨
#
# itr : 1154  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟨🟦🟥
# 🟥🟩🟩🟨
#
# itr : 1155  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟩🟥
# 🟥🟨🟦🟨
#
# itr : 1156  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟥
# 🟨🟥🟩🟨
#
# itr : 1157  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟨🟦
# 🟩🟩🟦🟥
# 🟥🟨🟨🟩
#
# itr : 1158  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟨🟩🟦🟦
# 🟥🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 1159  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟨🟩🟦🟦
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 1160  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟨🟩🟦🟦
# 🟩🟩🟦🟨
# 🟥🟩🟨🟨
#
# itr : 1161  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 1162  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 1163  depth: 3
# Board state:
# 🟥🟦🟥🟥
# 🟨🟩🟦🟦
# 🟩🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 1164  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟥🟩🟦
# 🟩🟩🟨🟦
# 🟥🟩🟨🟨
#
# itr : 1165  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟥🟦
# 🟥🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 1166  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟥🟦
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
#
# itr : 1167  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟨
# 🟥🟩🟨🟦
#
# itr : 1168  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟦
# 🟩🟥🟨🟨
#
# itr : 1169  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟥🟦
# 🟩🟩🟨🟦
# 🟥🟨🟩🟨
#
# itr : 1170  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟥🟩🟦🟥
# 🟨🟩🟨🟦
# 🟩🟩🟨🟨
#
# itr : 1171  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟥🟨🟦
# 🟩🟩🟨🟨
#
# itr : 1172  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟥🟨🟩🟦
# 🟩🟩🟨🟨
#
# itr : 1173  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟥🟩🟦🟨
# 🟩🟩🟨🟨
#
# itr : 1174  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟨
# 🟩🟩🟨🟦
#
# itr : 1175  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟥🟩🟨🟦
# 🟩🟨🟩🟨
#
# itr : 1176  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟨🟦🟥
# 🟩🟩🟩🟦
# 🟥🟩🟨🟨
#
# itr : 1177  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟩🟥
# 🟩🟨🟦🟦
# 🟥🟩🟨🟨
#
# itr : 1178  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟨🟩🟩🟦
# 🟥🟩🟨🟨
#
# itr : 1179  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟩🟩🟦
# 🟥🟨🟨🟨
#
# itr : 1180  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟨🟨🟦
# 🟥🟩🟩🟨
#
# itr : 1181  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟨🟦🟩
# 🟥🟩🟨🟨
#
# itr : 1182  depth: 3
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟨🟩🟨
# 🟥🟩🟨🟦
# //---------------------//
# Final Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟨🟩🟨
# 🟥🟩🟨🟦

# %%
#---A star Run---
a_star(board4x4)
# Out:
# A* Initial Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
# {"[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e6', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e6', '\\U0001f7e9', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e6', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e5'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e6'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e8'], ['\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e5', '\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e8', '\\U0001f7e8']]": <__main__.Board object at 0x7fc854766f10>, "[['\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6'], ['\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e6'], ['\\U0001f7e9', '\\U0001f7e9', '\\U000 ...
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟨🟩🟨
# 🟥🟩🟨🟦
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟨🟩🟦
# 🟥🟩🟨🟨
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟦
# 🟩🟨🟩🟥
# 🟥🟩🟨🟨
# Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟦
# 🟩🟩🟨🟥
# 🟥🟩🟨🟨
# //---------------------//
# Final Board state:
# 🟥🟦🟥🟦
# 🟨🟩🟦🟥
# 🟩🟨🟩🟨
# 🟥🟩🟨🟦

# %%
#print(json.dumps(stats, indent = 4))
jfile = json.dumps(stats, indent = 4)
print(jfile)
# Out:
# {
#     "bfs": {
#         "elapsed_time": 9.12026741200043,
#         "iters": 1182,
#         "path_length": 3,
#         "cpu": 21.6
#     },
#     "A*": {
#         "elapsed_time": 0.016341044000000693,
#         "iters": 4,
#         "path_length": 3,
#         "cpu": 4.4
#     }
# }

# %% [markdown]
# #Board 5x5 (Run A star only)

# %%
board5x5 = Board(int(5))
board5x5.input_state(5)
# Out:
# Enter the colour Board state as 5x5 matrix, elements separated by a ",":
# ['⬜️', '\U0001f7e6', '⬜️', '\U0001f7e9', '\U0001f7e6']
# ['⬜️', '⬜️', '\U0001f7e6', '\U0001f7e8', '\U0001f7e5']
# ['⬜️', '\U0001f7e6', '\U0001f7e5', '\U0001f7e6', '\U0001f7e9']
# ['\U0001f7e9', '\U0001f7e5', '\U0001f7e9', '\U0001f7e8', '\U0001f7e5']
# ['\U0001f7e8', '\U0001f7e8', '\U0001f7e5', '\U0001f7e9', '\U0001f7e8']

# %%
#---BFS Run---
#bfs(board5x5)
#---A star Run---
a_star(board5x5)
# Out:
# A* Initial Board state:
# ⬜️🟦⬜️🟩🟦
# ⬜️⬜️🟦🟨🟥
# ⬜️🟦🟥🟦🟩
# 🟩🟥🟩🟨🟥
# 🟨🟨🟥🟩🟨
# {"[['\\U0001f7e6', '⬜️', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '⬜️', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['⬜️', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '\\U0001f7e6', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['⬜️', '⬜️', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e8', '\\U0001f7e5'], ['⬜️', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['⬜️', '⬜️', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '\\U0001f7e6', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['⬜️', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '⬜️', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['⬜️', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '⬜️', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e6', '⬜️', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '⬜️', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['⬜️', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '⬜️', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['⬜️', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['\\U0001f7e9', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '⬜️', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['⬜️', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc853e49710>, "[['\\U0001f7e6', '⬜️', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['⬜️', '⬜️', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e9', '\\U0001f7e6', '\\U0001f7e5', '\\U0001f7e6', '\\U0001f7e9'], ['⬜️', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8', '\\U0001f7e5'], ['\\U0001f7e8', '\\U0001f7e8', '\\U0001f7e5', '\\U0001f7e9', '\\U0001f7e8']]": <__main__.Board object at 0x7fc85449c950>, "[['⬜️', '\\U0001f7e6', '⬜️', '\\U0001f7e9', '\\U0001f7e6'], ['\\U0001f7e9', '⬜️', '\\U0001f7e6', '\\U0001f7e8', '\\U0001f7e5'],  ...
# Board state:
# ⬜️🟦⬜️🟩🟦
# 🟩⬜️🟦🟨🟥
# ⬜️🟦🟥🟦🟩
# 🟨🟥🟩🟨🟥
# ⬜️🟨🟥🟩🟨
# Board state:
# ⬜️🟦⬜️🟩🟦
# 🟩⬜️🟦🟨🟥
# ⬜️🟦🟥🟦🟩
# ⬜️🟥🟩🟨🟥
# 🟨🟨🟥🟩🟨
# Board state:
# ⬜️🟦⬜️🟩🟦
# ⬜️⬜️🟦🟨🟥
# 🟩🟦🟥🟦🟩
# ⬜️🟥🟩🟨🟥
# 🟨🟨🟥🟩🟨
# Board state:
# ⬜️🟦⬜️🟩🟦
# ⬜️⬜️🟦🟨🟥
# ⬜️🟦🟥🟦🟩
# 🟩🟥🟩🟨🟥
# 🟨🟨🟥🟩🟨
# //---------------------//
# Final Board state:
# ⬜️🟦⬜️🟩🟦
# 🟩⬜️🟦🟨🟥
# ⬜️🟦🟥🟦🟩
# 🟨🟥🟩🟨🟥
# ⬜️🟨🟥🟩🟨

# %%
#print(json.dumps(stats, indent = 4))
jfile = json.dumps(stats, indent = 4)
print(jfile)
# Out:
# {
#     "bfs": {
#         "elapsed_time": 9.12026741200043,
#         "iters": 1182,
#         "path_length": 3,
#         "cpu": 21.6
#     },
#     "A*": {
#         "elapsed_time": 0.022159307000038098,
#         "iters": 4,
#         "path_length": 3,
#         "cpu": 6.0
#     }
# }
